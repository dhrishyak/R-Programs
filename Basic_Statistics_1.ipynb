# %% [markdown]
# # BASIC STATISTICS

# %% [markdown]
# ### Descriptive Analytics for Numerical Columns

# %%
import pandas as pd

# %%
sales_data=pd.read_csv('/content/sales_data_with_discounts.csv')
sales_data
# Out:
#            Date       Day  SKU City  Volume         BU  Brand       Model  \
# 0    01-04-2021  Thursday  M01    C      15    Mobiles  RealU       RU-10
# 1    01-04-2021  Thursday  M02    C      10    Mobiles  RealU   RU-9 Plus
# 2    01-04-2021  Thursday  M03    C       7    Mobiles   YouM       YM-99
# 3    01-04-2021  Thursday  M04    C       6    Mobiles   YouM  YM-99 Plus
# 4    01-04-2021  Thursday  M05    C       3    Mobiles   YouM      YM-98
# ..          ...       ...  ...  ...     ...        ...    ...         ...
# 445  15-04-2021  Thursday  L06    C       2  Lifestyle  Jeera   M-Casuals
# 446  15-04-2021  Thursday  L07    C       6  Lifestyle   Viva   W-Western
# 447  15-04-2021  Thursday  L08    C       2  Lifestyle   Viva    W-Lounge
# 448  15-04-2021  Thursday  L09    C       3  Lifestyle  Jeera   M-Formals
# 449  15-04-2021  Thursday  L10    C       1  Lifestyle  Jeera     M-Shoes
#
#      Avg Price  Total Sales Value  Discount Rate (%)  Discount Amount  \
# ...

# %%
sales_data.head()
# Out:
#          Date       Day  SKU City  Volume       BU  Brand       Model  \
# 0  01-04-2021  Thursday  M01    C      15  Mobiles  RealU       RU-10
# 1  01-04-2021  Thursday  M02    C      10  Mobiles  RealU   RU-9 Plus
# 2  01-04-2021  Thursday  M03    C       7  Mobiles   YouM       YM-99
# 3  01-04-2021  Thursday  M04    C       6  Mobiles   YouM  YM-99 Plus
# 4  01-04-2021  Thursday  M05    C       3  Mobiles   YouM      YM-98
#
#    Avg Price  Total Sales Value  Discount Rate (%)  Discount Amount  \
# 0      12100             181500          11.654820     21153.498820
# 1      10100             101000          11.560498     11676.102961
# 2      16100             112700           9.456886     10657.910157
# 3      20100             120600           6.935385      8364.074702
# 4       8100              24300          17.995663      4372.946230
#
#    Net Sales Value
# 0    160346.501180
# 1     89323.897039
# 2    102042.089843
# 3    112235.925298
# 4     19927.053770

# %%
sales_data.dtypes
# Out:
# Date                  object
# Day                   object
# SKU                   object
# City                  object
# Volume                 int64
# BU                    object
# Brand                 object
# Model                 object
# Avg Price              int64
# Total Sales Value      int64
# Discount Rate (%)    float64
# Discount Amount      float64
# Net Sales Value      float64
# dtype: object

# %%
sales_data.describe()
# Out:
#            Volume     Avg Price  Total Sales Value  Discount Rate (%)  \
# count  450.000000    450.000000         450.000000         450.000000
# mean     5.066667  10453.433333       33812.835556          15.155242
# std      4.231602  18079.904840       50535.074173           4.220602
# min      1.000000    290.000000         400.000000           5.007822
# 25%      3.000000    465.000000        2700.000000          13.965063
# 50%      4.000000   1450.000000        5700.000000          16.577766
# 75%      6.000000  10100.000000       53200.000000          18.114718
# max     31.000000  60100.000000      196400.000000          19.992407
#
#        Discount Amount  Net Sales Value
# count       450.000000       450.000000
# mean       3346.499424     30466.336131
# std        4509.902963     46358.656624
# min          69.177942       326.974801
# 25%         460.459304      2202.208645
# 50%         988.933733      4677.788059
# 75%        5316.495427     47847.912852
# ...

# %%
sales_data.select_dtypes(include=["int","float"])
# Out:
#      Volume  Avg Price  Total Sales Value  Discount Rate (%)  Discount Amount  \
# 0        15      12100             181500          11.654820     21153.498820
# 1        10      10100             101000          11.560498     11676.102961
# 2         7      16100             112700           9.456886     10657.910157
# 3         6      20100             120600           6.935385      8364.074702
# 4         3       8100              24300          17.995663      4372.946230
# ..      ...        ...                ...                ...              ...
# 445       2       1300               2600          15.475687       402.367873
# 446       6       2600              15600          17.057027      2660.896242
# 447       2       1600               3200          18.965550       606.897606
# 448       3       1900               5700          16.793014       957.201826
# 449       1       3100               3100          15.333300       475.332295
#
#      Net Sales Value
# ...

# %%
print('Mean')
sales_data.describe().mean()
# Out:
# Mean
# Volume                  63.037284
# Avg Price            12673.542272
# Total Sales Value    42899.738716
# Discount Rate (%)       67.879202
# Discount Amount       5109.936373
# Net Sales Value      38979.669520
# dtype: float64

# %%
print('Median')
sales_data.describe().median()
# Out:
# Median
# Volume                   4.649135
# Avg Price             5775.000000
# Total Sales Value    19756.417778
# Discount Rate (%)       15.866504
# Discount Amount       2167.716579
# Net Sales Value      17572.062095
# dtype: float64

# %%
print('Mode')
sales_data.describe().mode()
# Out:
# Mode
#        Volume     Avg Price  Total Sales Value  Discount Rate (%)  \
# 0    1.000000    290.000000         400.000000           4.220602
# 1    3.000000    450.000000         450.000000           5.007822
# 2    4.000000    465.000000        2700.000000          13.965063
# 3    4.231602   1450.000000        5700.000000          15.155242
# 4    5.066667  10100.000000       33812.835556          16.577766
# 5    6.000000  10453.433333       50535.074173          18.114718
# 6   31.000000  18079.904840       53200.000000          19.992407
# 7  450.000000  60100.000000      196400.000000         450.000000
#
#    Discount Amount  Net Sales Value
# 0        69.177942       326.974801
# 1       450.000000       450.000000
# 2       460.459304      2202.208645
# 3       988.933733      4677.788059
# 4      3346.499424     30466.336131
# 5      4509.902963     46358.656624
# 6      5316.495427     47847.912852
# 7     25738.022194    179507.479049

# %%
print('Standarad Deviation')
sales_data.describe().std()
# Out:
# Standarad Deviation
# Volume                 156.651107
# Avg Price            20240.811541
# Total Sales Value    65919.153313
# Discount Rate (%)      154.508238
# Discount Amount       8575.337507
# Net Sales Value      60310.392648
# dtype: float64

# %% [markdown]
# ### Data Visualization

# %% [markdown]
# #### Histogram

# %%
import matplotlib.pyplot as plt

# %%
numerical_columns=sales_data.select_dtypes(include=["int","float"])
numerical_columns.hist(figsize=(12,10),edgecolor='black')
plt.show()

# %% [markdown]
# #### Interpretation

# %% [markdown]
# Volume: -> It shows negative skewness. That is the tail on the left side of the histogram is longer than the right side. -> There are no isolated bars or very high or low frequencies at the edges of the histogram. So outliers are not present.
#
# Avg Price: -> It shows negative skewness. That is the tail on the left side of the histogram is longer than the right side. -> There is very high frequencies at the edge of the histogram. So outliers are present.
#
# Total Sales Value: -> It shows negative skewness. That is the tail on the left side of the histogram is longer than the right side. -> There is very high frequencies at the edge of the histogram. So outliers are present.
#
# Discount Rate(%): -> It shows positive skewness. That is the tail on the right side of the histogram is longer than the left side. -> There is high frequencies at the edge of the histogram. So outliers are present.
#
# Discount Amount: -> It shows negative skewness. That is the tail on the left side of the histogram is longer than the right side. -> There is very high frequencies at the edge of the histogram. So outliers are present.
#
# Net Sales Value: -> It shows negative skewness. That is the tail on the left side of the histogram is longer than the right side. -> There is very high frequencies at the edge of the histogram. So outliers are present.

# %% [markdown]
# #### Boxplots

# %%
numerical_colums = sales_data.select_dtypes( include = ['int','float'])
numerical_colums.boxplot(figsize = (10,6))
plt.xlabel('Numerical Columns')
plt.ylabel('Values')
plt.show()

# %% [markdown]
# #### Bar Chart Analysis for Categorical Column:

# %%
sales_data.dtypes
# Out:
# Date                  object
# Day                   object
# SKU                   object
# City                  object
# Volume                 int64
# BU                    object
# Brand                 object
# Model                 object
# Avg Price              int64
# Total Sales Value      int64
# Discount Rate (%)    float64
# Discount Amount      float64
# Net Sales Value      float64
# dtype: object

# %%
categorical_columns = sales_data.select_dtypes(include=['object']).columns
categorical_columns
# Out:
# Index(['Date', 'Day', 'SKU', 'City', 'BU', 'Brand', 'Model'], dtype='object')

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
for column in categorical_columns:
    plt.figure(figsize=(8, 6))
    sns.countplot(data=sales_data, x=column)
    plt.title(f'Bar chart of {column}')
    plt.xlabel(column)
    plt.ylabel('Count')
    plt.xticks(rotation=45)
    plt.tight_layout()
    plt.show()

# %% [markdown]
# #### Standardization of Numerical Variables

# %% [markdown]
# Explain the concept of standardization (z-score normalization):
#
# Standardization, also known as z-score normalization, is a technique used in statistics and data analysis to transform data such that it has a mean of 0 and a standard deviation of 1. This process allows data from different scales to be compared directly by making the distribution of the data more consistent.

# %%
sales_data
# Out:
#            Date       Day  SKU City  Volume         BU  Brand       Model  \
# 0    01-04-2021  Thursday  M01    C      15    Mobiles  RealU       RU-10
# 1    01-04-2021  Thursday  M02    C      10    Mobiles  RealU   RU-9 Plus
# 2    01-04-2021  Thursday  M03    C       7    Mobiles   YouM       YM-99
# 3    01-04-2021  Thursday  M04    C       6    Mobiles   YouM  YM-99 Plus
# 4    01-04-2021  Thursday  M05    C       3    Mobiles   YouM      YM-98
# ..          ...       ...  ...  ...     ...        ...    ...         ...
# 445  15-04-2021  Thursday  L06    C       2  Lifestyle  Jeera   M-Casuals
# 446  15-04-2021  Thursday  L07    C       6  Lifestyle   Viva   W-Western
# 447  15-04-2021  Thursday  L08    C       2  Lifestyle   Viva    W-Lounge
# 448  15-04-2021  Thursday  L09    C       3  Lifestyle  Jeera   M-Formals
# 449  15-04-2021  Thursday  L10    C       1  Lifestyle  Jeera     M-Shoes
#
#      Avg Price  Total Sales Value  Discount Rate (%)  Discount Amount  \
# ...

# %%
numerical_colums = sales_data.select_dtypes( include = ['int','float'])

# %%
mean = sales_data.describe().mean()
std = sales_data.describe().std()

for column in numerical_colums:
    sales_data_standardized = (sales_data[column] - mean[column]) / std[column]

print("Standardized DataFrame:")
print(sales_data)
# Out:
# Standardized DataFrame:
#            Date       Day  SKU City  Volume         BU  Brand       Model  \
# 0    01-04-2021  Thursday  M01    C      15    Mobiles  RealU       RU-10
# 1    01-04-2021  Thursday  M02    C      10    Mobiles  RealU   RU-9 Plus
# 2    01-04-2021  Thursday  M03    C       7    Mobiles   YouM       YM-99
# 3    01-04-2021  Thursday  M04    C       6    Mobiles   YouM  YM-99 Plus
# 4    01-04-2021  Thursday  M05    C       3    Mobiles   YouM      YM-98
# ..          ...       ...  ...  ...     ...        ...    ...         ...
# 445  15-04-2021  Thursday  L06    C       2  Lifestyle  Jeera   M-Casuals
# 446  15-04-2021  Thursday  L07    C       6  Lifestyle   Viva   W-Western
# 447  15-04-2021  Thursday  L08    C       2  Lifestyle   Viva    W-Lounge
# 448  15-04-2021  Thursday  L09    C       3  Lifestyle  Jeera   M-Formals
# 449  15-04-2021  Thursday  L10    C       1  Lifestyle  Jeera     M-Shoes
#
# ...

# %%
for col in numerical_colums:
    plt.figure(figsize=(10, 6))
    plt.subplot(1, 2, 1)
    sales_data[col].plot(kind='hist', bins=50)
    plt.title('Before Standardization')
    plt.xlabel(col)
    plt.ylabel('Frequency')

    plt.subplot(1, 2, 2)
    sales_data_standardized.plot(kind='hist', bins=50)
    plt.title('After Standardization')
    plt.xlabel(col + 'standardized')
    plt.ylabel('Frequency')
    plt.show()

# %% [markdown]
# ### Conversion of Categorical Data into Dummy Variables

# %% [markdown]
# Discuss the need for converting categorical data into dummy variables (one-hot encoding):
#
# One-hot encoding is a technique to convert categorical data into binary vectors, where each category is represented by a binary column (0 or 1). This is necessary because many machine learning algorithms cannot handle categorical data directly.

# %%
# Apply one-hot encoding to categorical columns
sales_data_onehot = pd.get_dummies(sales_data, columns=categorical_columns)
sales_data_onehot
# Out:
#      Volume  Avg Price  Total Sales Value  Discount Rate (%)  Discount Amount  \
# 0        15      12100             181500          11.654820     21153.498820
# 1        10      10100             101000          11.560498     11676.102961
# 2         7      16100             112700           9.456886     10657.910157
# 3         6      20100             120600           6.935385      8364.074702
# 4         3       8100              24300          17.995663      4372.946230
# ..      ...        ...                ...                ...              ...
# 445       2       1300               2600          15.475687       402.367873
# 446       6       2600              15600          17.057027      2660.896242
# 447       2       1600               3200          18.965550       606.897606
# 448       3       1900               5700          16.793014       957.201826
# 449       1       3100               3100          15.333300       475.332295
#
# ...

# %%
# Create a new DataFrame with the standardized numerical columns and the one-hot encoded categorical columns
sales_data_transformed = pd.concat([sales_data_standardized, sales_data_onehot.drop(columns=numerical_colums)], axis=1)
sales_data_transformed
# Out:
#      Net Sales Value  Date_01-04-2021  Date_02-04-2021  Date_03-04-2021  \
# 0           2.012370             True            False            False
# 1           0.834752             True            False            False
# 2           1.045631             True            False            False
# 3           1.214654             True            False            False
# 4          -0.315909             True            False            False
# ..               ...              ...              ...              ...
# 445        -0.609879            False            False            False
# 446        -0.431776            False            False            False
# 447        -0.603322            False            False            False
# 448        -0.567678            False            False            False
# 449        -0.602798            False            False            False
#
#      Date_04-04-2021  Date_05-04-2021  Date_06-04-2021  Date_07-04-2021  \
# ...

# %%
# Display a portion of the transformed dataset
print(sales_data_transformed.head(10))
# Out:
#    Net Sales Value  Date_01-04-2021  Date_02-04-2021  Date_03-04-2021  \
# 0         2.012370             True            False            False
# 1         0.834752             True            False            False
# 2         1.045631             True            False            False
# 3         1.214654             True            False            False
# 4        -0.315909             True            False            False
# 5        -0.311883             True            False            False
# 6         1.570646             True            False            False
# 7         1.048098             True            False            False
# 8         1.045498             True            False            False
# 9         2.046403             True            False            False
#
#    Date_04-04-2021  Date_05-04-2021  Date_06-04-2021  Date_07-04-2021  \
# 0            False            False            False            False
# ...
